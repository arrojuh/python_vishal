# %% [markdown]
# <a href="https://colab.research.google.com/github/arrojuh/python_vishal/blob/main/data_analysis%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/MTA_Daily_Ridership.csv")

# %%
df
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 0                                            97
# 1                                            96
# 2                                            98
# 3                                            99
# 4                                            99
# ...

# %%
df.shape
# Out:
# (1706, 15)

# %%
df.columns
# Out:
# Index(['Date', 'Subways: Total Estimated Ridership',
#        'Subways: % of Comparable Pre-Pandemic Day',
#        'Buses: Total Estimated Ridership',
#        'Buses: % of Comparable Pre-Pandemic Day',
#        'LIRR: Total Estimated Ridership',
#        'LIRR: % of Comparable Pre-Pandemic Day',
#        'Metro-North: Total Estimated Ridership',
#        'Metro-North: % of Comparable Pre-Pandemic Day',
#        'Access-A-Ride: Total Scheduled Trips',
#        'Access-A-Ride: % of Comparable Pre-Pandemic Day',
#        'Bridges and Tunnels: Total Traffic',
#        'Bridges and Tunnels: % of Comparable Pre-Pandemic Day',
#        'Staten Island Railway: Total Estimated Ridership',
#        'Staten Island Railway: % of Comparable Pre-Pandemic Day'],
#       dtype='object')

# %%
df.loc[1]
# Out:
# Date                                                       2020-03-02
# Subways: Total Estimated Ridership                            5329915
# Subways: % of Comparable Pre-Pandemic Day                          96
# Buses: Total Estimated Ridership                              2209066
# Buses: % of Comparable Pre-Pandemic Day                            99
# LIRR: Total Estimated Ridership                                321569
# LIRR: % of Comparable Pre-Pandemic Day                            103
# Metro-North: Total Estimated Ridership                         180701
# Metro-North: % of Comparable Pre-Pandemic Day                      66
# Access-A-Ride: Total Scheduled Trips                            30338
# Access-A-Ride: % of Comparable Pre-Pandemic Day                   102
# Bridges and Tunnels: Total Traffic                             874619
# Bridges and Tunnels: % of Comparable Pre-Pandemic Day              95
# ...

# %%
df.iloc[1]
# Out:
# Date                                                       2020-03-02
# Subways: Total Estimated Ridership                            5329915
# Subways: % of Comparable Pre-Pandemic Day                          96
# Buses: Total Estimated Ridership                              2209066
# Buses: % of Comparable Pre-Pandemic Day                            99
# LIRR: Total Estimated Ridership                                321569
# LIRR: % of Comparable Pre-Pandemic Day                            103
# Metro-North: Total Estimated Ridership                         180701
# Metro-North: % of Comparable Pre-Pandemic Day                      66
# Access-A-Ride: Total Scheduled Trips                            30338
# Access-A-Ride: % of Comparable Pre-Pandemic Day                   102
# Bridges and Tunnels: Total Traffic                             874619
# Bridges and Tunnels: % of Comparable Pre-Pandemic Day              95
# ...

# %%
df
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 0                                            97
# 1                                            96
# 2                                            98
# 3                                            99
# 4                                            99
# ...

# %%
df[['Date','Subways: Total Estimated Ridership']]
# Out:
#             Date  Subways: Total Estimated Ridership
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
# [1706 rows x 2 columns]

# %%
df[df['Date']>'2024-10-29']
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 1704                                         77
# 1705                                         70
#
#       Buses: Total Estimated Ridership  \
# 1704                           1553250
# 1705                           1297891
#
#       Buses: % of Comparable Pre-Pandemic Day  \
# 1704                                       69
# 1705                                       58
#
#       LIRR: Total Estimated Ridership  LIRR: % of Comparable Pre-Pandemic Day  \
# 1704                           267007                                      85
# 1705                           257756                                      82
#
#       Metro-North: Total Estimated Ridership  \
# 1704                                  246035
# 1705                                  221856
#
# ...

# %%
df[(df['Date']>'2024-10-29')&(df['Subways: % of Comparable Pre-Pandemic Day']>75)]
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 1704  2024-10-30                             4450028
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 1704                                         77
#
#       Buses: Total Estimated Ridership  \
# 1704                           1553250
#
#       Buses: % of Comparable Pre-Pandemic Day  \
# 1704                                       69
#
#       LIRR: Total Estimated Ridership  LIRR: % of Comparable Pre-Pandemic Day  \
# 1704                           267007                                      85
#
#       Metro-North: Total Estimated Ridership  \
# 1704                                  246035
#
#       Metro-North: % of Comparable Pre-Pandemic Day  \
# 1704                                             85
#
#       Access-A-Ride: Total Scheduled Trips  \
# 1704                                 40468
#
#       Access-A-Ride: % of Comparable Pre-Pandemic Day  \
# 1704                                              136
#
# ...

# %%
df.dtypes
# Out:
# Date                                                       object
# Subways: Total Estimated Ridership                          int64
# Subways: % of Comparable Pre-Pandemic Day                   int64
# Buses: Total Estimated Ridership                            int64
# Buses: % of Comparable Pre-Pandemic Day                     int64
# LIRR: Total Estimated Ridership                             int64
# LIRR: % of Comparable Pre-Pandemic Day                      int64
# Metro-North: Total Estimated Ridership                      int64
# Metro-North: % of Comparable Pre-Pandemic Day               int64
# Access-A-Ride: Total Scheduled Trips                        int64
# Access-A-Ride: % of Comparable Pre-Pandemic Day             int64
# Bridges and Tunnels: Total Traffic                          int64
# Bridges and Tunnels: % of Comparable Pre-Pandemic Day       int64
# Staten Island Railway: Total Estimated Ridership            int64
# ...

# %%
df['Subways: % of Comparable Pre-Pandemic Day'].dtype
# Out:
# dtype('int64')

# %%
df['Subways: % of Comparable Pre-Pandemic Day'].astype('float')
# Out:
# 0       97.0
# 1       96.0
# 2       98.0
# 3       99.0
# 4       99.0
#         ...
# 1701    90.0
# 1702    69.0
# 1703    76.0
# 1704    77.0
# 1705    70.0
# Name: Subways: % of Comparable Pre-Pandemic Day, Length: 1706, dtype: float64

# %%
df['Subways: % of Comparable Pre-Pandemic Day'] = df['Subways: % of Comparable Pre-Pandemic Day'].astype('float')

# %%
df
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 0                                          97.0
# 1                                          96.0
# 2                                          98.0
# 3                                          99.0
# 4                                          99.0
# ...

# %%
df['test']= df['Metro-North: % of Comparable Pre-Pandemic Day']/10

# %%
df
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 0                                          97.0
# 1                                          96.0
# 2                                          98.0
# 3                                          99.0
# 4                                          99.0
# ...

# %%
df
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 0     2020-03-01                             2212965
# 1     2020-03-02                             5329915
# 2     2020-03-03                             5481103
# 3     2020-03-04                             5498809
# 4     2020-03-05                             5496453
# ...          ...                                 ...
# 1701  2024-10-27                             2215973
# 1702  2024-10-28                             3985381
# 1703  2024-10-29                             4391065
# 1704  2024-10-30                             4450028
# 1705  2024-10-31                             4027166
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 0                                            97
# 1                                            96
# 2                                            98
# 3                                            99
# 4                                            99
# ...

# %%
df2 = df[(df['Buses: % of Comparable Pre-Pandemic Day']>40)&(df['Buses: % of Comparable Pre-Pandemic Day']<60)]

# %%
df3 = df2.reset_index(drop = True)

# %%
df3
# Out:
#            Date  Subways: Total Estimated Ridership  \
# 0    2020-03-16                             2178555
# 1    2020-03-17                             1788786
# 2    2020-03-18                             1625280
# 3    2020-03-19                             1422112
# 4    2020-09-01                             1469274
# ..          ...                                 ...
# 609  2024-09-04                             3868854
# 610  2024-10-03                             3630794
# 611  2024-10-04                             3507603
# 612  2024-10-14                             3067003
# 613  2024-10-31                             4027166
#
#      Subways: % of Comparable Pre-Pandemic Day  \
# 0                                           39
# 1                                           32
# 2                                           29
# 3                                           26
# 4                                           25
# ..                                         ...
# ...

# %%
## Join and Merge

## Join will join on index

# %%
df.join(df3,lsuffix = '_y',rsuffix = '_x',how = 'inner')
# Out:
#          Date_y  Subways: Total Estimated Ridership_y  \
# 0    2020-03-01                               2212965
# 1    2020-03-02                               5329915
# 2    2020-03-03                               5481103
# 3    2020-03-04                               5498809
# 4    2020-03-05                               5496453
# ..          ...                                   ...
# 609  2021-10-31                               1746769
# 610  2021-11-01                               3034306
# 611  2021-11-02                               2848222
# 612  2021-11-03                               3293732
# 613  2021-11-04                               3284315
#
#      Subways: % of Comparable Pre-Pandemic Day_y  \
# 0                                             97
# 1                                             96
# 2                                             98
# 3                                             99
# 4                                             99
# ...

# %%
df.join(df2,lsuffix = '_y',rsuffix = '_x',how = 'right')
# Out:
#           Date_y  Subways: Total Estimated Ridership_y  \
# 15    2020-03-16                               2178555
# 16    2020-03-17                               1788786
# 17    2020-03-18                               1625280
# 18    2020-03-19                               1422112
# 184   2020-09-01                               1469274
# ...          ...                                   ...
# 1648  2024-09-04                               3868854
# 1677  2024-10-03                               3630794
# 1678  2024-10-04                               3507603
# 1688  2024-10-14                               3067003
# 1705  2024-10-31                               4027166
#
#       Subways: % of Comparable Pre-Pandemic Day_y  \
# 15                                             39
# 16                                             32
# 17                                             29
# 18                                             26
# ...

# %%
df.merge(df2,how = 'inner')
# Out:
#            Date  Subways: Total Estimated Ridership  \
# 0    2020-03-16                             2178555
# 1    2020-03-17                             1788786
# 2    2020-03-18                             1625280
# 3    2020-03-19                             1422112
# 4    2020-09-01                             1469274
# ..          ...                                 ...
# 609  2024-09-04                             3868854
# 610  2024-10-03                             3630794
# 611  2024-10-04                             3507603
# 612  2024-10-14                             3067003
# 613  2024-10-31                             4027166
#
#      Subways: % of Comparable Pre-Pandemic Day  \
# 0                                           39
# 1                                           32
# 2                                           29
# 3                                           26
# 4                                           25
# ..                                         ...
# ...

# %%
##'select * from df inner join df2 on df.Date == df2.'Date2'

# %%
##JOIN -- joins on index(no columns required)
##MERGE --- joins on columns if specified(else join on index if columns are not specified)
##MERGE -- use on if same column exists in both dataframes, else use left_on for column in left and right_on column in right
